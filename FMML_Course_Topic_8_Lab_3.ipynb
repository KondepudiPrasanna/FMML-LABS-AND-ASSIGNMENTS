# %% [markdown]
# <a href="https://colab.research.google.com/github/KondepudiPrasanna/FMML-LABS-AND-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-07 15:20:32--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   186MB/s    in 0.4s
#
# 2024-04-07 15:20:33 (186 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22906  1710.06595v2  Robustness to outliers is a central issue in r...  stat
# 38935   1402.4893v4  Triangular meshes have gained much interest in...    cs
# 21636   1209.0016v2  Maximum Variance Unfolding is one of the main ...  stat
# 1172    1312.4384v1  We attack the problem of learning concepts aut...    cs
# 15372   1410.2082v2  Word alignment is an important natural languag...    cs
# ...             ...                                                ...   ...
# 6258   1610.05925v1  We propose a new class of determinantal point ...  stat
# 17716  1802.03238v1  Sequence-to-sequence (Seq2seq) models have pla...    cs
# 13802  1504.08117v3  In evolutionary optimization, it is important ...    cs
# 18165  cs/0501086v1  This paper presents an approach to enhance sea...    cs
# 7834   1803.07276v1  The rapid development of deep learning methods...  stat
#
#                                                    title  year  \
# 22906  Variational Inference based on Robust Divergences  2017
# 38935  Anisotropic Mesh Adaptation for Image Represen...  2014
# 21636   On the convergence of maximum variance unfolding  2012
# 1172   Rectifying Self Organizing Maps for Automatic ...  2013
# 15372  Contrastive Unsupervised Word Alignment with N...  2014
# ...                                                  ...   ...
# 6258   Learning Determinantal Point Processes in Subl...  2016
# 17716  Recurrent Neural Network-Based Semantic Variat...  2018
# 13802  Average Convergence Rate of Evolutionary Algor...  2015
# 18165  Clever Search: A WordNet Based Wrapper for Int...  2005
# 7834   Fair Deep Learning Prediction for Healthcare A...  2018
#
#                                                 keywords
# 22906  [robustness, applications, replacing, robustif...
# 38935  [triangular, representation, processing, intro...
# 21636  [unfolding, dimensionality, reduction, providi...
# 1172   [automatically, attributes, categories, discov...
# 15372  [alignment, important, processing, indicates, ...
# ...                                                  ...
# 6258   [determinantal, processes, manipulated, infere...
# 17716  [processing, translation, summarization, recog...
# 13802  [evolutionary, optimization, important, unders...
# 18165  [information, available, information, conceptu...
# 7834   [development, permitted, structured, applicati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22906    [robustness, applications, replacing, robustif...
# 38935    [triangular, representation, processing, intro...
# 21636    [unfolding, dimensionality, reduction, providi...
# 1172     [automatically, attributes, categories, discov...
# 15372    [alignment, important, processing, indicates, ...
#                                ...
# 24805    [pedestrian, detection, representations, pedes...
# 39214    [characterization, instrumental, astronomical,...
# 1116     [stochastic, transition, application, generate...
# 6945     [interactive, algorithm, recovering, engineeri...
# 34192    [selection, frequencies, considered, attribute...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8846 words.
# Out of those 4553 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="810dfc6a-b679-464a-8adb-00eb60535376" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("810dfc6a-b679-464a-8adb-00eb60535376")) {                    Plotly.newPlot(                        "810dfc6a-b679-464a-8adb-00eb60535376",                        [{"x":["activation","inference","functions","formulation","outperforms","divergence","unbounded","replacing","variational","applications","robustness","divergences","demonstrate","regression","classification","advantage","experimentally","theoretically","optimization","flexibility","anisotropic","represent","adaptation","triangular","introduces","reconstruction","implementation","processing","mathematical","computational","technique","different","framework","representation","developed","providing","reduction","convergence","dimensionality","assumptions","consistent","underlying","isometric","unfolding","submanifold","organizing","automatic","categories","instances","collection","exploiting","irrelevant","discovering","clustering","supervision","representing","characteristics","competitive","detection","eliminating","available","automatically","attributes","knowledge","differentiate","indicates","experiments","approximate","alignments","considerable","concentrated","discriminative","correspondence","partition","posterior","observation","probability","efficient","calculate","distributions","unsupervised","important","generative","improvements","approaches","alignment","expectations","calculation","significant","contrastive","languages","intractable","attention","challenge","capturing","questionable","techniques","experience","including","convolutional","classifier","descriptors","additionally","unfortunately","benchmark","intelligent","extraction","determine","autonomous","illumination","generation","employing","scenarios","reconstruct","technologies","generating","reconstructions","interactive","describing","discusses","investigation","eventually","evidences","carefully","systematic","considerations","sophisticated","acquiring","realistic","informative","performance","dimensions","information","descriptor","corresponding","determined","redundant","comparable","selection","estimation","situations","explosion","configurations","combinatorial","independently","lipschitz","computing","propagated","interestingly","arbitrary","experiment","distributed","components","computation","distinguish","preceding","continuous","leveraged","unnecessary","propagation","assessing","detectors","introduce","description","repeatedly","synthetic","performing","locations","homography","repeatability","supervised","associated","traditional","combining","parameters","adaptivity","established","univariate","multivariate","distributional","strategies","practical","establish","complication","demonstrates","dimensional","guarantees","grassmannian","sequences","simplified","identification","submanifolds","importantly","validation","extensive","computationally","segmenting","advocates","segmentation","theoretical"],"y":[33,203,216,84,269,21,3,9,54,388,99,4,564,112,499,86,52,41,286,27,12,117,66,2,76,100,116,266,50,299,271,694,540,345,194,72,85,113,61,79,102,116,2,2,1,12,195,72,96,67,90,20,28,155,56,75,102,124,350,19,327,172,76,356,11,22,611,97,13,46,8,89,18,17,47,64,173,384,19,137,122,338,113,103,427,53,8,25,221,9,115,26,149,153,47,1,355,35,254,360,135,30,66,32,207,65,139,70,55,40,136,34,105,17,28,108,12,44,39,19,28,10,3,33,47,17,28,13,69,40,870,53,691,30,141,42,28,97,189,217,56,8,19,48,39,10,128,8,12,85,70,96,99,145,31,2,99,5,10,66,11,42,332,78,14,142,79,44,4,2,186,124,163,114,252,1,63,5,29,17,100,128,46,2,45,172,70,3,101,22,104,0,31,53,159,76,19,0,224,143],"type":"bar"},{"x":["activation","inference","func ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4553,), (4553, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Design</span> <span style=''>of</span> <span style=''>Image</span> <span style=''>Matched</span> <span style=''>Non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Separable</span> <span style=''>Wavelet</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Network</span> <br/><br/><span style=''>Image</span> <span style=''>matched</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonseparable</span> <span style=''>wavelets</span> <span style=''>can</span> <span style=''>find</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>use</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>segmen</span> <span style=''>tation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compressive</span> <span style=''>sensing</span> <span style=''>etc</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>that</span> <span style=''>utilizes</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>convolutional</span> <span style=''>neural</span> <span style=''>net</span> <span style=''>work</span> <span style=''>(CNN)</span> <span style=''>to</span> <span style=''>design</span> <span style=''>two</span> <span style=''>channel</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separable</span> <span style=''>wavelet</span> <span style=''>matched</span> <span style=''>to</span> <span style=''>a</span> <span style=''>given</span> <span style=''>image</span> <span style=''>The</span> <span style=''>design</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>on</span> <span style=''>quin</span> <span style=''>cunx</span> <span style=''>lattice</span> <span style=''>The</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>is</span> <span style=''>setup</span> <span style=''>with</span> <span style=''>total</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>between</span> <span style=''>the</span> <span style=''>given</span> <span style=''>input</span> <span style=''>image</span> <span style=''>to</span> <span style=''>CNN</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>reconstructed</span> <span style=''>image</span> <span style=''>at</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>CNN</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>perfect</span> <span style='background-color:rgba(0, 255, 0, 0.38888888888888884);'>reconstruction</span> <span style=''>at</span> <span style=''>the</span> <span style=''>end</span> <span style=''>of</span> <span style=''>train</span> <span style=''>ing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Simulation</span> <span style=''>results</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>on</span> <span style=''>some</span> <span style=''>standard</span> <span style=''>images</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dynamical</span> <span style=''>Systems</span> <br/><br/><span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>time</span> <span style=''>series</span> <span style=''>are</span> <span style=''>endemic</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>such</span> <span style=''>as</span> <span style=''>robotics</span> <span style=''>(sensor</span> <span style=''>data)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>biology</span> <span style=''>(gene</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expression</span> <span style=''>data)</span> <span style=''>vision</span> <span style=''>(video</span> <span style=''>sequences)</span> <span style=''>and</span> <span style=''>graphics</span> <span style=''>(motion</span> <span style=''>capture</span> <span style=''>data)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>this</span> <span style=''>data</span> <span style=''>are</span> <span style=''>required</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>system</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>builds</span> <span style=''>on</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>with</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>prior</span> <span style=''>in</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>space</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>also</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>space</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>model</span> <span style=''>on< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>linear</span> <span style=''>time</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>choosing</span> <span style=''>a</span> <span style=''>density</span> <span style=''>estimate</span> <span style=''>from</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>F</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style=''>L1</span> <span style=''>distance</span> <span style=''>to</span> <span style=''>an</span> <span style=''>unknown</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>(Devroye</span> <span style=''>Lugosi</span> <span style=''>2001)</span> <span style=''>Devroye</span> <span style=''>and</span> <span style=''>Lugosi</span> <span style=''>analyze</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>Scheffe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tournament</span> <span style=''>winner</span> <span style=''>and</span> <span style=''>minimum</span> <span style=''>distance</span> <span style=''>estimate</span> <span style=''>The</span> <span style=''>Scheffe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tournament</span> <span style=''>estimate</span> <span style=''>requires</span> <span style=''>fewer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>than</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>distance</span> <span style=''>estimate</span> <span style=''>but</span> <span style=''>has</span> <span style=''>strictly</span> <span style=''>weaker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>than</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>aspect</span> <span style=''>of</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>We</span> <span style=''>present</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>both</span> <span style=''>with</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>as</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>distance</span> <span style=''>estimate</span> <span style=''>The</span> <span style=''>first</span> <span style=''>one</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>distance</span> <span style=''>estimate</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>same</span> <span style=''>number</span> <span style=''>(quadratic</span> <span style=''>in</span> <span style=''>|F|)</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computations</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Scheffe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tournament</span> <span style=''>The</span> <span style=''>second</span> <span style=''>one</span> <span style=''>called</span> <span style='background-color:rgba(0, 25 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>reducing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>LMS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <br/><br/><span style=''>The</span> <span style=''>rise</span> <span style=''>of</span> <span style=''>digital</span> <span style=''>and</span> <span style=''>mobile</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>communications</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>made</span> <span style=''>the</span> <span style=''>world</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>networked</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unprecedented</span> <span style=''>volume</span> <span style=''>of</span> <span style=''>data</span> <span style=''>flowing</span> <span style=''>between</span> <span style=''>sources</span> <span style=''>data</span> <span style=''>centers</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>While</span> <span style=''>these</span> <span style=''>data</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>centralized</span> <span style=''>manner</span> <span style=''>it</span> <span style=''>is</span> <span style=''>often</span> <span style=''>more</span> <span style=''>suitable</span> <span style=''>to</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>as</span> <span style=''>they</span> <span style=''>are</span> <span style=''>scalable</span> <span style=''>and</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>large</span> <span style=''>amounts</span> <span style=''>of</span> <span style=''>data</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributing</span> <span style=''>tasks</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>networked</span> <span style=''>agents</span> <span style=''>Although</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>simple</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>over</span> <span style=''>a</span> <span style=''>cluster</span> <span style=''>it</span> <span style=''>appears</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>to</span> <span style=''>deploy</span> <span style=''>them</span> <span style=''>in</span> <span style=''>an</span> <span style=''>ad</span> <span style=''>hoc</span> <span style=''>network</span> <span style=''>with</span> <span style=''>limited</span> <span style=''>energy</span> <span style=''>budget</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style=''>In</span> <span style='' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.0941385435168739)
# 	automatic (0.06927175843694494)
# 	architecture (0.09200710479573712)
# 	information (0.24547069271758437)
# 	knowledge (0.12646536412078152)
# 	different (0.24653641207815274)
# 	segmentation (0.07957371225577264)
# 	detection (0.12433392539964476)
# 	convolutional (0.12788632326820604)
# 	recognition (0.136056838365897)
#
# Some Statistics words are:
# 	statistical (0.15214105793450883)
# 	algorithms (0.28513853904282116)
# 	theoretical (0.14710327455919395)
# 	stochastic (0.13904282115869018)
# 	estimation (0.1748110831234257)
# 	distribution (0.19143576826196473)
# 	algorithm (0.3994962216624685)
# 	dimensional (0.19042821158690176)
# 	regression (0.17229219143576827)
# 	inference (0.21158690176322417)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5bed1d18-83c8-4e2d-b802-b9523f3f67d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bed1d18-83c8-4e2d-b802-b9523f3f67d4")) {                    Plotly.newPlot(                        "5bed1d18-83c8-4e2d-b802-b9523f3f67d4",                        [{"x":["activation","inference","functions","formulation","outperforms","divergence","unbounded","replacing","variational","applications","robustness","divergences","demonstrate","regression","classification","advantage","experimentally","theoretically","optimization","flexibility","anisotropic","represent","adaptation","triangular","introduces","reconstruction","implementation","processing","mathematical","computational","technique","different","framework","representation","developed","providing","reduction","convergence","dimensionality","assumptions","consistent","underlying","isometric","unfolding","submanifold","organizing","automatic","categories","instances","collection","exploiting","irrelevant","discovering","clustering","supervision","representing","characteristics","competitive","detection","eliminating","available","automatically","attributes","knowledge","differentiate","indicates","experiments","approximate","alignments","considerable","concentrated","discriminative","correspondence","partition","posterior","observation","probability","efficient","calculate","distributions","unsupervised","important","generative","improvements","approaches","alignment","expectations","calculation","significant","contrastive","languages","intractable","attention","challenge","capturing","questionable","techniques","experience","including","convolutional","classifier","descriptors","additionally","unfortunately","benchmark","intelligent","extraction","determine","autonomous","illumination","generation","employing","scenarios","reconstruct","technologies","generating","reconstructions","interactive","describing","discusses","investigation","eventually","evidences","carefully","systematic","considerations","sophisticated","acquiring","realistic","informative","performance","dimensions","information","descriptor","corresponding","determined","redundant","comparable","selection","estimation","situations","explosion","configurations","combinatorial","independently","lipschitz","computing","propagated","interestingly","arbitrary","experiment","distributed","components","computation","distinguish","preceding","continuous","leveraged","unnecessary","propagation","assessing","detectors","introduce","description","repeatedly","synthetic","performing","locations","homography","repeatability","supervised","associated","traditional","combining","parameters","adaptivity","established","univariate","multivariate","distributional","strategies","practical","establish","complication","demonstrates","dimensional","guarantees","grassmannian","sequences","simplified","identification","submanifolds","importantly","validation","extensive","computationally","segmenting","advocates","segmentation","theoretical","geodesics","constructs","intersect","deviations","directional","thoroughly","intrinsic","riemannian","algorithm","application","irrational","essentially","decisions","correlation","incomplete","limitations","marginalization","inconsistent","revisited","rationality","therefore","intelligence","irrespective","artificial","extension","imperfect","superpixel","effective","benchmarks","particular","conventional","pedestrian","generated","euclidian","extracted","clustered","generally","mahalanobis","graphical","assimilating","demonstrating","constructed","algorithms","counterparts","numerical","partially","relational","architecture","generalizes","localized","templates","biological","complexity","repre ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	submanifolds
# 	advocates
# 	subgradient
# 	physiologic
# 	nonparanormal
# 	worsening
# 	heteroscedasticity
# 	exposition
# 	disentangles
# 	unintentionally
# 	directionally
# 	asymptotics
# 	heteroskedastic
# 	circumvents
# 	impression
# 	underestimated
# 	reformulates
# 	cytometry
# 	emphmulti
# 	penalization
# Some words which never appear in Statistics papers:
# 	illumination
# 	evidences
# 	homography
# 	repeatability
# 	irrational
# 	superpixel
# 	ultrasound
# 	forgeries
# 	predominant
# 	stylometry
# 	agreements
# 	panchromatic
# 	parallelepiped
# 	conversational
# 	histology
# 	gutenberg
# 	concurrent
# 	installed
# 	interictal
# 	declarative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.057823441274501e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7325
